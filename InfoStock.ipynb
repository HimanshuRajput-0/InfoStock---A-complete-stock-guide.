# %% [markdown]
# <a href="https://colab.research.google.com/github/HimanshuRajput-0/InfoStock---A-complete-stock-guide./blob/main/InfoStock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests

# %%
import requests  #for asking data

# %%
API_KEY = "1d400b889d24478c93c8693a202dbe51"

# %%
def get_stock_news(company_name):

    url = (
        f"https://newsapi.org/v2/everything?"
        f"q={company_name}&"
        f"language=en&"
        f"sortBy=publishedAt&"
        f"pageSize=5&"
        f"apiKey={API_KEY}"
    )

    response = requests.get(url)

    if response.status_code != 200:
        return []

    data = response.json()

    return data["articles"]

# %%
company = input("Enter Company Name: ")

articles = get_stock_news(company)

for idx, article in enumerate(articles, start=1):
    print(f"\n{idx}. {article['title']}")
# Out:
# Enter Company Name: Wipro
#
# 1. Cement sector faces muted Q1 FY27 as heat, water scarcity hit demand: Ashika's Jyoti Gupta
#
# 2. Last Opportunity to Apply: JKSHIM and NMIT Announce Final MBA Application Window for 2026-27 Academic Session - The Tribune
#
# 3. Markets choppy at midday, IT stocks drag as Maruti surges nearly 5%
#
# 4. Sensex, Nifty trade flat after sharp swings; Eicher Motors, TCP, Infosys, Wipro, TCS among top losers
#
# 5. Nifty IT hits fresh 52-week low as Infosys, TCS, Wipro & others tumble up to 3%. What's spooking investors?
